# %% [markdown]
# # Generating higher order dispersion gifs

# %%
from ssfm_functions import *
import numpy as np

# %% [markdown]
# # Set up time base and input signal

# %%
os.chdir(os.path.realpath(os.path.dirname('F:\\GitHub\\Repository\\Nlse\\NLSE-vector-solver')))
    
    
N  = 2**16 #Number of points
dt = 10e-15 #Time resolution [s] 

centerWavelength=1550e-9
centerFreq=wavelengthToFreq(centerWavelength)


timeFreq_test=timeFreq_class(N,dt,centerFreq)

testAmplitude = np.sqrt(1)                    #Amplitude in units of sqrt(W)
testDuration  =1e-11   #Pulse 1/e^2 duration [s]
testOffset    = 0                       #Time offset
testChirp = 0
testCarrierFreq=0
testPulseType='gaussian' 
testOrder = 1
testNoiseAmplitude = 0


testInputSignal = input_signal_class(timeFreq_test, 
                                      testAmplitude ,
                                      testDuration,
                                      testOffset,
                                      testChirp,
                                      testCarrierFreq,
                                      testPulseType,
                                      testOrder,
                                      testNoiseAmplitude)
# Out:
#  ### timeFreq Configuration Parameters ###
#   Number of points 		= 65536
#   Start time, tmin 		= -327.680ps
#   Stop time, tmax 		= 327.680ps
#   Time resolution 		= 0.010ps
#
#   Center frequency		= 193.414THz
#   Start frequency		= -49.999THz
#   Stop frequency 		= 49.998THz
#   Frequency resolution 		= 1525.856MHz
#
#  ### Input Signal Parameters ###
#   Pmax 				= 1.000 W
#   Duration 			= 10.000 ps
#   Time offset 			= 0.000 ps
#   Freq offset 			= 0.000 GHz
#   Chirp 			= 0.000
#   pulseType 			= gaussian
#   order 			= 1
#   noiseAmplitude 		= 0.000 sqrt(W)

# %% [markdown]
# # Fiber with only 7th order dispersion

# %%
beta_list = [0,0,0,0,0,1e-12*1e-24*1e-11] #Dispersion in units of s^(entry+2)/m    


#  Initialize fiber
fiber_beta4 = fiber_class(1000, 2**8, 0,   beta_list,    0  )


fiber_list_beta4 = [fiber_beta4]
fiber_span_beta4 = fiber_span_class(fiber_list_beta4)

testSafetyFactor = 10
testStepConfig=("fixed",2**11,testSafetyFactor)

expName="beta7"
#Run SSFM
ssfm_result_list = SSFM(fiber_span_beta4,testInputSignal,
                        # stepConfig=testStepConfig,
                        experimentName=expName,showProgressFlag=True)


#Plot pulses
nrange_test_pulse=9600
cutoff_test_pulse=-60

#Plot pulses
nrange_test_spectrum=200
cutoff_test_spectrum=-60
# Out:
#  ### Characteristic parameters of fiber: ###
# Fiber Length [km] 	= 1.0
# Number of Steps 	= 256
# dz [m] 	= 3.90625
# Fiber gamma [1/W/m] 	= 0
# Fiber beta2 [s^2/m] 	= 0
# Fiber beta3 [s^3/m] 	= 0
# Fiber beta4 [s^4/m] 	= 0
# Fiber beta5 [s^5/m] 	= 0
# Fiber beta6 [s^6/m] 	= 0
# Fiber beta7 [s^7/m] 	= 9.999999999999999e-48
# Fiber beta8 [s^8/m] 	= 0.0
# Fiber alpha_dB_per_m 	= 0
# Fiber alpha_Np_per_m 	= 0.0
# Fiber total loss [dB] 	= 0
# Raman Model 	= None. (fR,tau1,tau2)=(0.0,0.0,0.0)
#
# ########### Initializing SSFM!!! ###########
# Current time is 2023-05-06 14:16:06.683668
# Current dir is F:\GitHub\Repository\Dispersion\HighOrderDispersion\Dispersion7\Simulation Results\beta7\2023_5_6_14_16_6\
# Starting SSFM loop over 1 fibers
# Propagating through fiber number 1 out of 1
# Info about fiber
#  ### Characteristic parameters of fiber: ###
# Fiber Length [km] 	= 1.0
# Number of Steps 	= 256
# dz [m] 	= 3.90625
# Fiber gamma [1/W/m] 	= 0
# Fiber beta2 [s^2/m] 	= 0
# Fiber beta3 [s^3/m] 	= 0
# Fiber beta4 [s^4/m] 	= 0
# Fiber beta5 [s^5/m] 	= 0
# Fiber beta6 [s^6/m] 	= 0
# Fiber beta7 [s^7/m] 	= 9.999999999999999e-48
# Fiber beta8 [s^8/m] 	= 0.0
# Fiber alpha_dB_per_m 	= 0
# Fiber alpha_Np_per_m 	= 0.0
# Fiber total loss [dB] 	= 0
# Raman Model 	= None. (fR,tau1,tau2)=(0.0,0.0,0.0)
#
#
#  ### Characteristic parameters of simulation: ###
#   Length_fiber 	= 1.00e+00 km
#   Length_disp_7 	= 1.00e-33 km
#   Length_NL 	= 1.00e+97 km
#   N_soliton 	= nan
#   N_soliton^2 	= nan
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 16
#      14 expName="beta7"
#      15 #Run SSFM
# ---> 16 ssfm_result_list = SSFM(fiber_span_beta4,testInputSignal,
#      17                         # stepConfig=testStepConfig,
#      18                         experimentName=expName,showProgressFlag=True)
#      21 #Plot pulses
#      22 nrange_test_pulse=9600
#
# File f:\GitHub\Repository\Dispersion\HighOrderDispersion\Dispersion7\ssfm_functions.py:1605, in SSFM(fiber_span, input_signal, experimentName, showProgressFlag)
#    1602 spectrum = getSpectrumFromPulse(current_input_signal.timeFreq.t, current_input_signal.amplitude)*disp_and_loss_half_step
#    1604 #spectrum = np.copy(current_input_signal.spectrum )*disp_and_loss_half_step
# -> 1605 pulse    = getPulseFromSpectrum(input_signal.timeFreq.f, spectrum)
#    1607 #
#    1608 #Apply half dispersion step
#    1609 #Start loop
#    (...)
#    1612 #End loop
#    1613 #Apply half dispersion step
#    1616 print(f"Running SSFM with {fiber.numberOfSteps} steps")
#
# File f:\GitHub\Repository\Dispersion\HighOrderDispersion\Dispersion7\ssfm_functions.py:458, in getPulseFromSpectrum(frequency_Hz, spectrum_amplitude)
#     454 pulseEnergy = getEnergy(time, pulse)
#     456 err=np.abs((pulseEnergy/spectrumEnergy-1))
# --> 458 assert( err<1e-7   ), f'ERROR = {err}: Energy changed when going from Spectrum to Pulse!!!'
#     460 return pulse
#
# AssertionError: ERROR = 3.332125074750891e-07: Energy changed when going from Spectrum to Pulse!!!

# %% [markdown]
# # Plot everything

# %%
plotEverythingAboutResult(ssfm_result_list,
                          nrange_test_pulse,
                          cutoff_test_pulse,
                          nrange_test_spectrum,
                          cutoff_test_spectrum,
                          )
# Out:
# number_of_fibers = 1
# number_of_fibers = 1
# length of zvals = 257
# number_of_fibers = 1
# number_of_fibers = 1
# number_of_fibers = 1
# number_of_fibers = 1
# number_of_fibers = 1

# %% [markdown]
# # Gif of 7th order dispersion

# %%
makeChirpGif(ssfm_result_list,nrange_test_pulse,chirpRange=[-20,20],framerate=30)
# Out:
# Making .gif anination of pulse evolution. This may take a while, so please be patient.
# The .gif animation will be saved in F:\GitHub\Repository\Dispersion\HighOrderDispersion\Dispersion7\Simulation Results\beta7\2023_5_6_14_10_7
# number_of_fibers = 1
